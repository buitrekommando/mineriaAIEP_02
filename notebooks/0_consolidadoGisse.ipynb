# %% [markdown]
# ## *Evaluación de Actividad 1*
# # Introduccion a la minería, análisis de  Taco Sales

# %% [markdown]
# <img src="../img/logoAIEP.jpg" alt="Logo de AIEP" width="300">
#
# <div class="alert alert-block alert-info">
#
#    <b>Estudiantes:</b><br>
#     Camila García<br>
#     José Luis Henríquez<br>
#     Gisselle Rey<br>
#     Marcos Zuñiga<br>
#     Gabriela Osbelis Nogera<br>
#
#  </div>

# %% [markdown]
# Taba de contenidos<br>
#
# [1 Conocer el negocio](#conocer-el-negocio)<br>
# [2 Conocer los Datos](#0-conocer-los-datos)<br>
# [3 preguntas](#7-preguntas-de-negocio)<br>
# [4 Limpieza de Datos](#limpieza-de-datos)<br>

# %% [markdown]
# # 1. Conocer el Negocio
# ### Análisis del Negocio Taco Sales (2024–2025)
# #  **Taco** **Sales** Dataset 🌮
#
#
#
# Taco Sales es una empresa del sector gastronómico especializada en la venta de tacos bajo un modelo de comida rápida y delivery inteligente. Se trata de un negocio que combina la tradición de la cocina mexicana con una operación moderna, centrada en el uso intensivo de datos operacionales, logísticos y comerciales y tambien representa un modelo de negocio híbrido ya que tambien funciona tanto presencial y delivery, diseñado para operar con una ventaja competitiva basada en la inteligencia de datos como lo son Data-Driven Intelligence. La organización fusiona la oferta de un producto de alta demanda con una infraestructura tecnológica que captura y procesa datos transaccionales, logísticos y el comportamiento del cliente en tiempo real.
#
# ### La propuesta de valor del negocio
# Taco Sales no solo se basa en ofrecer tacos deliciosos, personalizables y accesibles, sino en la eficiencia operativa, la tecnología aplicada y el enfoque estratégico basado en datos para su crecimiento.
#
# Y la ventaja competitiva de Taco Sales se construye sobre los siguientes pilares que son muy fundamentales:
#
# **Producto** **atractivo**: Tacos artesanales, adaptables, en distintos tamaños y con múltiples combinaciones.
#
# **Velocidad** **y** **conveniencia**: Modelo express orientado a reducir tiempos de espera. Digitalización y monitoreo: Seguimiento en tiempo real de pedidos, stock y tiempos.
#
# **Toma** **de** **decisiones** basada en datos: Análisis continuo para ajustar menús, precios, promociones y logística.
#
# ### Modelo del negocio
# Taco Sales opera a través de una red de restaurantes ubicados en ciudades como:
#
# - New York
#
# - Dallas
#
# - Austin
#
# - San Antonio,
#
# Utilizando un modelo híbrido de atención: como presencial (en tienda)
# Delivery (propio o a través de plataformas como DoorDash y Uber Eats)
# Cada punto de venta funciona con una estructura ágil, enfocada en tiempos de preparación reducidos, variedad de combinaciones, y una experiencia estandarizada para el cliente.
#
# ### Qué datos utiliza este negocio
#
# Uno de los principales diferenciales de Taco Sales es que cada interacción del cliente genera datos clave para la toma de decisiones y las variable	en el uso estratégico y asi obtener datos importantes como hora y fecha del pedido	Identificación de patrones de demanda por franja y estacionalidad
#
# En este negocio tambien es importante los datos como la ubicación del cliente,
# segmentación geográfica, planificación logística, tamaño y tipo de taco	Análisis de preferencia del consumidor, cantidad de toppings	Personalización  control de costos, tiempo de entrega	Evaluación de eficiencia operativa,distancia recorrida	Optimización de rutas y reducción de costos, propina entregada	Indicador indirecto de satisfacción del cliente, comparación de comportamiento entre días hábiles y fines de semana
#
#
# ### Posicionamiento estratégico del negocio
#
# Taco Sales no compite únicamente por sabor o precio, sino por inteligencia operativa. Mientras muchos negocios gastronómicos se basan en intuición o experiencia previa, Taco Sales avanza con decisiones respaldadas por datos. Esto le permite:
#
# Detectar tendencias antes que la competencia
# Reducir costos operativos sin afectar la calidad
# Diseñar promociones segmentadas por cliente o ciudad
# Prever picos de demanda y reforzar recursos en tiempo real
#
# ### Por qué es replicable este modelo?
#
# Taco Sales es un ejemplo moderno de cómo la gastronomía puede cruzarse con la ciencia de datos. Su negocio no solo ofrece un producto exitoso y deseado, sino que está diseñado para aprender constantemente del comportamiento del cliente, adaptarse con rapidez y crecer con inteligencia. Este proyecto permite analizar no solo los datos de venta, sino también el funcionamiento interno de una organización preparada para el futuro digital del rubro alimenticio.
# ¿Quieres que prepare este texto como celda Markdown para Google Colab o que lo exporte a Word o PDF? También puedo hacer una versión con gráficas o visuales del modelo de negocio si tu entrega lo requiere.
#
# ### Problemas de Negocio que Aborda el Dataset de Ventas de Tacos
#
# 1. fluctuación en la Demanda:
# Uno de los principales problemas de la industria gastronómica, especialmente en la comida rápida, es la fluctuación en la demanda. Esto puede generar desperdicios de comida o falta de insumos. El dataset puede ayudar a analizar las variaciones de demanda en diferentes días, semanas o meses, y así poder prever con más precisión la cantidad de ingredientes necesarios para cada día.
#
# 2. optimización de Inventarios:
# Sin un sistema adecuado de gestión de inventarios, los negocios pueden enfrentar pérdidas de productos perecederos como tortillas, carne, salsa, etc. Con los datos del dataset, los dueños de los restaurantes pueden optimizar el control de insumos, reduciendo desperdicios y mejorando la rentabilidad.
#
# 3. identificación de Tendencias de Consumo:
# Este dataset ofrece una visión importante sobre qué tipo de tacos tienen mayor demanda, en qué zonas geográficas se consume más y en qué días de la semana se concentran los pedidos. Esto ayuda a las marcas a realizar una planificación adecuada de su producción y estrategia de marketing.
#
# ### Oportunidades para el Negocio de Tacos en Chile
#
# Expansión en Nuevas Zonas Geográficas:
# El análisis de las zonas con mayor demanda puede revelar nuevas oportunidades de expansión. Un negocio exitoso de tacos podría considerar abrir nuevas ubicaciones en zonas con alta densidad poblacional o expandirse a ciudades fuera de Santiago, como Viña del Mar o Concepción, donde la comida mexicana comienza a ser más popular.
#
# Promociones Específicas:
# Con la información sobre los días de mayor y menor demanda, las marcas pueden diseñar ofertas y promociones para los días más tranquilos, como el lunes o martes, aumentando las ventas en días de baja demanda.
#
# Personalización de Menú:
# Adaptarse a las preferencias locales también es una forma de innovar. Ofrecer tacos con ingredientes que resuenen con los gustos de los chilenos, como tacos de pescado frito, carne de cordero o incluso tacos con productos típicos como avellanas y frutillas puede atraer a más clientes.

# %% [markdown]
# ### Este Codigo Es el modelo Pipeline que mostrata el **conjunto de procesos o etapas de este Negocio**

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# --- Datos del pipeline ---
data_pipeline = {
    'Captura del Dato': [
        'Ubicación del cliente',
        'Tipo y tamaño de taco',
        'Cantidad de toppings',
        'Tiempo de entrega',
        'Distancia recorrida',
        'Propina entregada',
        'Patrones de día'
    ],
    'Análisis Aplicado': [
        'Segmentación geográfica',
        'Análisis de preferencias',
        'Control de costos',
        'Evaluación de eficiencia',
        'Optimización de rutas',
        'Medición de satisfacción',
        'Análisis comparativo'
    ],
    'Decisión Estratégica': [
        'Planificación de marketing',
        'Ingeniería de menú',
        'Ajuste de precios',
        'Mejora de operaciones',
        'Reducción de gastos',
        'Programas de lealtad',
        'Gestión de demanda'
    ]
}

# --- Configuración del gráfico ---
fig, ax = plt.subplots(figsize=(18, 8))
fig.patch.set_facecolor('#F1F3F5')  # Fondo general suave

# Colores para etapas
etapa_colores = ['#0D47A1', '#1976D2', '#42A5F5']  # Gama profesional azul

# Posiciones horizontales de las etapas
x_pos = [0.15, 0.5, 0.85]
etapas = list(data_pipeline.keys())
y_pos = 0.5

# Estilo de las cajas
box_style = dict(boxstyle='round,pad=0.5', fc='white', ec='#CED4DA', lw=1.8)
arrow_style = dict(arrowstyle='-|>', color='#343A40', lw=2, mutation_scale=18)

# Dibujar cajas y títulos
for i, etapa in enumerate(etapas):
    x = x_pos[i]
    items = '\n'.join(f'• {line}' for line in data_pipeline[etapa])

    # Texto de la etapa
    ax.text(x, y_pos, items,
            ha='center', va='center',
            fontsize=11, color='#495057',
            bbox=box_style, linespacing=1.5)

    # Título superior de cada etapa
    ax.text(x, 0.9, f'{i+1}. {etapa}',
            ha='center', va='center',
            fontsize=15, fontweight='bold',
            color=etapa_colores[i])

# Flechas entre etapas
for i in range(len(x_pos) - 1):
    arrow = patches.FancyArrowPatch(
        (x_pos[i] + 0.13, y_pos),
        (x_pos[i+1] - 0.13, y_pos),
        connectionstyle="arc3,rad=0.2",
        **arrow_style
    )
    ax.add_patch(arrow)

# Formato final
ax.axis('off')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Eliminar la lupa y modificar el título
plt.suptitle('Pipeline de Inteligencia de Negocio – Taco Sales',
             fontsize=22, fontweight='bold', color='#212529', y=0.98)

plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %% [markdown]
# ### En este codigo se mostrara la **linea de tiempo** historica del negocio
#
# La siguiente línea de tiempo muestra los hitos más relevantes del desarrollo del modelo Taco Sales, desde su conceptualización hasta su proyección de expansión a Chile.

# %%
# %pip install matplotlib

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Datos de los eventos
eventos = {
    "Fecha": ["2020-01-01", "2021-06-15", "2022-03-10", "2023-08-05", "2024-01-01", "2025-06-01"],
    "Hito": [
        "Inicio del negocio", "Primera sucursal en Austin", "Sistema de pedidos",
        "Expansión a otras ciudades", "Optimización logística", "Evaluación del mercado chileno"
    ],
    "Fase": ["Inicio", "Validación", "Tecnología", "Expansión", "Optimización", "Evaluación"]
}

# Crear DataFrame
df = pd.DataFrame(eventos)
df["Fecha"] = pd.to_datetime(df["Fecha"])

# Colores para cada fase
colores = {"Inicio": "#FFB74D", "Validación": "#4CAF50", "Tecnología": "#2196F3",
           "Expansión": "#FF5722", "Optimización": "#9C27B0", "Evaluación": "#00BCD4"}

# Crear gráfico
fig, ax = plt.subplots(figsize=(10, 5))
for i, row in df.iterrows():
    ax.plot(row["Fecha"], 1, "o", color=colores[row["Fase"]], markersize=10)
    ax.text(row["Fecha"], 1.1, row["Hito"], ha='center', va='bottom', fontsize=9, rotation=45)

ax.set_title("Línea de Tiempo - Avance del Negocio", fontsize=14)
ax.set_xticks(pd.to_datetime(df["Fecha"]))
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.get_yaxis().set_visible(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ***
# # 2. Conocer los datos

# %% [markdown]
# Este conjunto de datos contiene 1,000 registros de pedidos de entrega de tacos, generados entre el 1 de enero de 2024 y el 25 de mayo de 2025. <br>Simula datos realistas de restaurantes ubicados en varias ciudades de Estados Unidos e incluye información como:
# <div class="alert alert-block alert-info">
#
#
# - `Order ID` _ID de Pedido_: Identificador único para cada pedido de tacos
# - `Restaurant` Name _Nombre del Restaurante_: Nombre del restaurante de tacos
# - `Location` _Ubicación_: Ciudad de EE. UU. donde se realizó el pedido
# - `Order Time` _Hora del Pedido_: Marca de tiempo cuando se realizó el pedido (AAAA-MM-DD HH:MM:SS)
# - `Delivery Time` _Hora de Entrega_: Marca de tiempo cuando se entregó el pedido
# - `Delivery Duration` (min) _Duración de Entrega (minutos)_: Minutos transcurridos desde el pedido hasta la entrega
# - `Taco Size` _Tamaño del Taco_: Tamaño del taco solicitado: Regular o Grande
# - `Taco type` _Tipo de Taco_: Tipo de taco (por ejemplo, Res, Pollo, Vegetariano, Pescado, Cerdo)
# - `Toppings Count` _Cantidad de Aderezos_: Número de aderezos extra añadidos.
# - `Distance (km)` _Distancia (km)_: Distancia desde el restaurante hasta el cliente
# - `Price ($)` _Precio ($)_: Precio total del pedido, calculado según el tamaño y los aderezos
# - `Tip ($)` _Propina ($)_: Monto de la propina dada por el cliente
# - `Weekend Order` _Pedido en Fin de Semana_: Booleano, VERDADERO si el pedido se realizó en fin de semana.
# </div>

# %% [markdown]
# # 2.1 Los Datos.

# %%
import pandas as pd

# %% [markdown]
# Crear dataframe

# %%
df = pd.read_csv("../dataset/taco_sales_2024-2025.csv")

# %% [markdown]
# Mostrar dataframe

# %%
df
# Out:
#      Order ID   Restaurant Name     Location        Order Time  \
# 0      770487      El Taco Loco     New York  01-08-2024 14:55
# 1      671858      El Taco Loco  San Antonio  23-11-2024 17:11
# 2      688508        Taco Haven       Austin  21-11-2024 20:24
# 3      944962  Spicy Taco House       Dallas  21-09-2024 06:43
# 4      476417     Casa del Taco  San Antonio  24-07-2024 11:01
# ..        ...               ...          ...               ...
# 995    164891      La Vida Taco       Austin  27-05-2024 11:12
# 996    232442    The Taco Stand  San Antonio  03-04-2025 20:51
# 997    251729       Urban Tacos      Houston  23-01-2025 05:33
# 998    940215       Taco Fiesta  San Antonio  05-09-2024 15:49
# 999    326183      Grande Tacos      Phoenix  19-10-2024 14:21
#
#         Delivery Time  Delivery Duration (min) Taco Size     Taco Type  \
# 0    01-08-2024 15:36                       41   Regular  Chicken Taco
# ...

# %% [markdown]
# # 2.2 Estructura del dataframe.

# %% [markdown]
# Muestrar un resumen del DataFrame: <br>número de filas, columnas, tipos de datos, valores nulos, etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 1000 non-null   int64
#  1   Restaurant Name          1000 non-null   object
#  2   Location                 1000 non-null   object
#  3   Order Time               1000 non-null   object
#  4   Delivery Time            1000 non-null   object
#  5   Delivery Duration (min)  1000 non-null   int64
#  6   Taco Size                1000 non-null   object
#  7   Taco Type                1000 non-null   object
#  8   Toppings Count           1000 non-null   int64
#  9   Distance (km)            1000 non-null   float64
#  10  Price ($)                1000 non-null   float64
#  11  Tip ($)                  1000 non-null   float64
#  12  Weekend Order            1000 non-null   bool
# dtypes: bool(1), float64(3), int64(3), object(6)
# ...

# %% [markdown]
# # 2.3 Ver los diferentes valores de los atributos.

# %% [markdown]
# En El siguiente apartado analizaremos la frecuencia con la que se repiten los diferentes valores de los atributos para las columnas: Restaurant Name, Location, Taco Size, Taco Type, Weekend Order. para facilitar se mostratan por separado.

# %% [markdown]
# ### Restaurant Name

# %%
categorical_columns = ['Restaurant Name']

for col in categorical_columns:
    print(f"\n--- Frecuencia de valores en: {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frecuencia de valores en: Restaurant Name ---
# Restaurant Name
# Urban Tacos          117
# Grande Tacos         106
# The Taco Stand       105
# Casa del Taco        104
# Spicy Taco House     100
# Taco Fiesta           99
# La Vida Taco          98
# Taco Haven            95
# Taco Time Express     91
# El Taco Loco          85
# Name: count, dtype: int64

# %% [markdown]
# Al analizar los diferentes valores del atributo Restaurant Name, se identificó que existen 10 restaurantes distintos en el conjunto de datos. Este atributo es de tipo categórico y permite conocer de dónde provienen los pedidos.
#
# Se observó que los restaurantes con mayor cantidad de pedidos son Urban Tacos (117 pedidos), Grande Tacos (106) y The Taco Stand (105). Esta información puede ser útil en análisis posteriores, como estudiar el rendimiento de cada restaurante, comparar tiempos de entrega o evaluar la satisfacción del cliente según el lugar de origen del pedido.

# %% [markdown]
# ### Location

# %%
categorical_columns = ['Location']

for col in categorical_columns:
    print(f"\n--- Frecuencia de valores en: {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frecuencia de valores en: Location ---
# Location
# Chicago        116
# San Antonio    113
# San Diego      101
# Houston        101
# Los Angeles    101
# Phoenix         99
# San Jose        98
# New York        96
# Austin          95
# Dallas          80
# Name: count, dtype: int64

# %% [markdown]
# En el análisis del atributo Location, se identificaron 10 ubicaciones distintas donde se realizaron entregas de pedidos. Este atributo es de tipo categórico y representa la ciudad en la que se entregó cada pedido.
#
# Las ciudades con mayor volumen de pedidos fueron Chicago (116 pedidos), San Antonio (113) y San Diego/Houston/Los Angeles (cada una con 101 pedidos). Por el contrario, Dallas fue la ciudad con menor número de pedidos (80). Esta información puede ser clave para analizar la distribución geográfica de la demanda, planificar rutas de entrega o identificar oportunidades de expansión para los restaurantes.

# %% [markdown]
# ### Taco Size

# %%
categorical_columns = ['Taco Size']

for col in categorical_columns:
    print(f"\n--- Frecuencia de valores en: {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frecuencia de valores en: Taco Size ---
# Taco Size
# Regular    502
# Large      498
# Name: count, dtype: int64

# %% [markdown]
# El atributo Taco Size es una variable categórica que representa el tamaño de los tacos solicitados en cada pedido. En el dataset, solo existen dos tamaños: Regular y Large.
#
# La frecuencia de pedidos está casi equilibrada, con una ligera mayoría para los tacos Regular (502 pedidos) frente a los tacos Large (498 pedidos). Esta distribución balanceada indica que ambos tamaños son igualmente populares entre los clientes, lo cual puede influir en decisiones de inventario y marketing para cada restaurante.

# %% [markdown]
# ### Taco Type

# %%
categorical_columns = ['Taco Type']

for col in categorical_columns:
    print(f"\n--- Frecuencia de valores en: {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frecuencia de valores en: Taco Type ---
# Taco Type
# Chicken Taco    218
# Fish Taco       211
# Veggie Taco     197
# Pork Taco       192
# Beef Taco       182
# Name: count, dtype: int64

# %% [markdown]
# El atributo Taco Type representa el tipo de taco solicitado en cada pedido y contiene cinco categorías diferentes: pollo, pescado, vegetariano, cerdo y res.
#
# El tipo más popular es el Chicken Taco con 218 pedidos, seguido por el Fish Taco (211) y el Veggie Taco (197). Aunque el Beef Taco es el menos pedido con 182 solicitudes, la distribución general es bastante equilibrada, lo que sugiere que los clientes tienen variadas preferencias de sabores. Esta información es útil para la planificación del menú y la gestión de inventarios.

# %% [markdown]
# ###  Weekend Order

# %%
categorical_columns = ['Weekend Order']

for col in categorical_columns:
    print(f"\n--- Frecuencia de valores en: {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frecuencia de valores en: Weekend Order ---
# Weekend Order
# False    725
# True     275
# Name: count, dtype: int64

# %% [markdown]
# El atributo Weekend Order es una variable booleana que indica si el pedido fue realizado durante el fin de semana o no.
#
# Se observa que la mayoría de los pedidos (725) se realizaron en días laborales, mientras que 275 pedidos corresponden a fines de semana. Esto evidencia que aunque el volumen de pedidos es mayor durante la semana, los fines de semana también representan una parte significativa de la demanda, lo cual puede influir en la planificación de recursos y personal para los restaurantes.

# %% [markdown]
# # 2.4 Revisar la completitud de los datos.
#
# Usaremos df.isnull() para crear un DataFrame booleano donde True indica valores faltantes y usaremos .sum() para representar la suma de valores faltantes por columna.

# %%
df.isnull().sum()
# Out:
# Order ID                   0
# Restaurant Name            0
# Location                   0
# Order Time                 0
# Delivery Time              0
# Delivery Duration (min)    0
# Taco Size                  0
# Taco Type                  0
# Toppings Count             0
# Distance (km)              0
# Price ($)                  0
# Tip ($)                    0
# Weekend Order              0
# dtype: int64

# %% [markdown]
# Se realizó una revisión de la completitud de los datos para detectar la existencia de valores faltantes o nulos en el dataset. Utilizando funciones de pandas, se comprobó la cantidad de datos nulos por cada columna.
#
# El análisis mostró que no existen valores faltantes en ninguna de las 13 columnas, lo que indica que los datos están completos y no requieren imputación o limpieza por ausencia de información.

# %% [markdown]
# #  2.5 Mostrar estadísticas de los datos.

# %% [markdown]
# ### Estadísticas descriptivas para columnas numéricas
#
# Estadísticas para columnas numéricas. Se analiza la muestra estadísticas básicas como:
#
# * Cuenta (count)
# * Media (mean)
# * Desviación estándar (std)
# * Mínimo (min)
# * Cuartiles (25%, 50%, 75%)
# * Máximo (max)

# %%
df.describe()
# Out:
#             Order ID  Delivery Duration (min)  Toppings Count  Distance (km)  \
# count    1000.000000               1000.00000     1000.000000    1000.000000
# mean   552504.865000                 50.93000        2.529000      13.073420
# std    255948.779709                 23.22754        1.717005       7.142268
# min    101139.000000                 10.00000        0.000000       0.510000
# 25%    331796.750000                 30.00000        1.000000       6.972500
# 50%    559740.000000                 53.00000        3.000000      13.200000
# 75%    771781.750000                 71.00000        4.000000      19.242500
# max    999138.000000                 90.00000        5.000000      24.980000
#
#          Price ($)      Tip ($)
# count  1000.000000  1000.000000
# mean      6.908250     1.806110
# std       2.310137     1.132035
# min       3.000000     0.010000
# 25%       4.500000     0.907500
# 50%       6.750000     1.760000
# 75%       9.250000     2.520000
# ...

# %% [markdown]
# ### Estadísticas descriptivas para columnas categóricas (objetos y booleanos)
# Estadísticas para columnas categóricas.  Se revisa la muestra estadísticas para columnas categóricas y booleanas, como:
#
# * Cuenta (count)
# * Valores únicos (unique)
# * Valor más frecuente (top)
# * Frecuencia del valor más frecuente (freq)

# %%
df.describe(include=['object', 'bool'])
# Out:
#        Restaurant Name Location        Order Time     Delivery Time Taco Size  \
# count             1000     1000              1000              1000      1000
# unique              10       10              1000               999         2
# top        Urban Tacos  Chicago  01-08-2024 14:55  15-04-2025 16:06   Regular
# freq               117      116                 1                 2       502
#
#            Taco Type Weekend Order
# count           1000          1000
# unique             5             2
# top     Chicken Taco         False
# freq             218           725

# %% [markdown]
# Se calcularon estadísticas descriptivas para comprender mejor la distribución y características principales de los datos. Para las variables numéricas, se analizaron medidas de tendencia central y dispersión como la media, la desviación estándar, mínimos, máximos y cuartiles.
#
# Para las variables categóricas y booleanas, se obtuvo información sobre la cantidad de valores únicos, el valor más frecuente y su frecuencia, lo cual facilita entender la composición y predominancia de categorías en cada atributo.

# %% [markdown]
#  # 2.6 Explicar los datos utilizando gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="whitegrid")

# %% [markdown]
# ### Gráfico de barras: pedidos por tipo de taco

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Taco Type', order=df['Taco Type'].value_counts().index, palette="pastel")
plt.title('Cantidad de pedidos por tipo de taco')
plt.xlabel('Tipo de Taco')
plt.ylabel('Cantidad de Pedidos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gisse\AppData\Local\Temp\ipykernel_14324\2134800751.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Taco Type', order=df['Taco Type'].value_counts().index, palette="pastel")

# %% [markdown]
# El gráfico de barras muestra que el Chicken Taco es el tipo de taco más popular, seguido por el Fish Taco y el Veggie Taco. El Beef Taco presenta la menor cantidad de pedidos. Esta información es útil para conocer las preferencias de los clientes y puede apoyar decisiones como ajustes al menú, estrategias de promoción o planificación de inventario.

# %% [markdown]
# ### Gráfico de pastel: distribución por tamaño de taco

# %%
taco_size_counts = df['Taco Size'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(taco_size_counts, labels=taco_size_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ffcc99','#66b3ff'])
plt.title('Distribución de pedidos por tamaño de taco')
plt.axis('equal')
plt.show()

# %% [markdown]
# El gráfico de pastel muestra la proporción de pedidos según el tamaño del taco. Se observa que la distribución está prácticamente equilibrada entre tacos de tamaño Regular (50.2%) y Large (49.8%), lo que sugiere que ambos tamaños son igualmente populares entre los clientes. Esta información es valiosa para la toma de decisiones sobre producción, promociones o gestión de stock, ya que indica una demanda balanceada entre las dos opciones.

# %% [markdown]
# ### Gráfico de barras: pedidos por ciudad (Location)

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Location', order=df['Location'].value_counts().index, palette="Set2")
plt.title('Cantidad de pedidos por ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Pedidos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gisse\AppData\Local\Temp\ipykernel_14324\168993181.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Location', order=df['Location'].value_counts().index, palette="Set2")

# %% [markdown]
# El gráfico de barras muestra la distribución de pedidos por ciudad. Se observa que Chicago (116 pedidos) y San Antonio (113 pedidos) lideran en volumen de pedidos, lo cual podría deberse a mayor demanda local, mayor cantidad de restaurantes o una operación más eficiente en esas zonas.
#
# Por otro lado, Dallas presenta el menor número de pedidos (80), lo que podría indicar menor penetración del servicio en esa ciudad o menor densidad de población objetivo. Esta visualización permite identificar las ciudades con mayor y menor actividad, útil para enfocar estrategias comerciales, logísticas o promocionales.

# %% [markdown]
# ### Gráfico de cajas (boxplot): propinas por tipo de taco

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Taco Type', y='Tip ($)', palette="coolwarm")
plt.title('Distribución de propinas según tipo de taco')
plt.xlabel('Tipo de Taco')
plt.ylabel('Propina ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gisse\AppData\Local\Temp\ipykernel_14324\2333725631.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Taco Type', y='Tip ($)', palette="coolwarm")

# %% [markdown]
# El gráfico boxplot analiza la distribución de propinas entregadas según el tipo de taco pedido. Se observa que las medianas son similares entre los diferentes tipos, oscilando entre $1.5 y $2.5. Esto indica que el tipo de taco no influye significativamente en la cantidad de propina.
#
# Sin embargo, tipos como el Chicken Taco y Pork Taco muestran mayor dispersión y algunos valores máximos más altos, lo cual podría deberse a entregas excepcionales o clientes más generosos. También se detectan algunos valores atípicos en los tacos de res y pescado, indicando propinas inusuales.

# %% [markdown]
# ### Histograma: duración de entregas

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Delivery Duration (min)'], bins=20, kde=True, color='skyblue')
plt.title('Distribución de la duración de entrega')
plt.xlabel('Minutos')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %% [markdown]
# Se utilizaron distintos tipos de gráficos para analizar y comunicar visualmente los datos del conjunto.
# * Gráficos de barras permitieron observar la distribución de pedidos según tipo de taco, tamaño y ubicación.
# * Gráficos de pastel ayudaron a visualizar proporciones (por ejemplo, tamaños de taco).
# * Boxplots mostraron la variabilidad en las propinas según el tipo de taco.
# * Histogramas revelaron cómo se distribuye el tiempo de entrega.
#
# Estos gráficos facilitan la identificación de patrones, preferencias de los clientes y posibles valores extremos en los datos.

# %% [markdown]
# # 3. Preguntas de negocio

# %% [markdown]
# >###  3.1 ¿Cuál es el taco que más se consume?

# %%
import matplotlib.pyplot as plt

# Agrupar por tipo de taco y contar cuántos pedidos hay de cada uno
taco_sales = df.groupby('Taco Type').size().sort_values(ascending=False)

# Crear gráfico de torta
plt.figure(figsize=(8, 6))
plt.pie(taco_sales, labels=taco_sales.index, autopct='%1.1f%%', startangle=140)
plt.title('Proporción de Ventas por Tipo de Taco')
plt.axis('equal')  # Asegura que el gráfico sea circular
plt.show()

# %% [markdown]
# El taco que más se consume es el Chicken Taco.

# %% [markdown]
# >### 3.2 ¿Qué restaurante hace mas ventas?

# %%
import matplotlib.pyplot as plt

restaurant_counts = df.groupby('Restaurant Name').size().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
restaurant_counts.plot(kind='bar', color='orange')

plt.title('Cantidad de Pedidos por Restaurante')
plt.xlabel('Restaurante')
plt.ylabel('Cantidad de Pedidos')
plt.xticks(rotation=45, ha='right')  # Rotar etiquetas para mejor lectura
plt.tight_layout()
plt.show()

# %% [markdown]
# El restaurant que hace mas ventas es el Urban Tacos

# %% [markdown]
# >### 3.3 ¿Hay restaurantes que entregan más lejos que otros?

# %%
avg_distance = df.groupby('Restaurant Name')['Distance (km)'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 5))
avg_distance.plot(kind='bar', color='salmon')
plt.title('Top 10 Restaurantes con Mayor Distancia Promedio de Entrega')
plt.xlabel('Restaurante')
plt.ylabel('Distancia Promedio (km)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Grande Tacos es el restaurant con mayor distancia promedio de entrega de tacos.

# %% [markdown]
# ***

# %% [markdown]
# # 4. Limpieza de datos

# %% [markdown]
# # 4.1 Tratamiendo de valores nulos o faltantes
#
# El metodo df.isnull() nos devolvera un DataFrame booleano con *True* donde hay valores nulos.
#
# Para el caso de nuestro DataFrame, no se encuentran valores *nulos*

# %%
df.isnull()
# Out:
#      Order ID  Restaurant Name  Location  Order Time  Delivery Time  \
# 0       False            False     False       False          False
# 1       False            False     False       False          False
# 2       False            False     False       False          False
# 3       False            False     False       False          False
# 4       False            False     False       False          False
# ..        ...              ...       ...         ...            ...
# 995     False            False     False       False          False
# 996     False            False     False       False          False
# 997     False            False     False       False          False
# 998     False            False     False       False          False
# 999     False            False     False       False          False
#
#      Delivery Duration (min)  Taco Size  Taco Type  Toppings Count  \
# 0                      False      False      False           False
# ...

# %% [markdown]
# El metedo *df.isnull().sum()*, cuenta cuántos nulos hay por columna.
# Lo usamos para corroborar la informacion de anterior de el metodo *df.isnull()*

# %%
df.isnull().sum()
# Out:
# Order ID                   0
# Restaurant Name            0
# Location                   0
# Order Time                 0
# Delivery Time              0
# Delivery Duration (min)    0
# Taco Size                  0
# Taco Type                  0
# Toppings Count             0
# Distance (km)              0
# Price ($)                  0
# Tip ($)                    0
# Weekend Order              0
# dtype: int64

# %% [markdown]
# Para los casos en donde el dataset contenga valores nulos, se pueden utilizar los de metodos de *df.dropna()* que sirve para eliminar las filas o columnas con valores nulos y
# el metodo *df.fillna(valor)* que nos ayuda a rellenar los valores nulos con algun valor especifico en caso de necesitarlo

# %% [markdown]
# ## 4.2 Eliminacion de duplicados
#
# *df.duplicated()* devolvera un booleano por columna indicando si es duplicada

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>NOTA:</b> Esto se realizo netamente para mostrar el uso de la herramienta
# </div>

# %% [markdown]
# En caso que el dataset contenga filas duplicadas se puede utilizar df.drop_duplicate(filaDuplicada) para eliminarlas.

# %% [markdown]
# ## 4.3 Conversiones de Datos
# Convertir los datos en fundamental para el analisis, ya que nos permite la estandarización del dataset y asegura la compatibilidad

# %% [markdown]
# Se cambia el formato de la columna Order Time de tipo  object a datatime y se separa la columna en: <br>
# "Order Day"<br>
# "Order Hour"<br>
# "Order Minute"<br>
# "Orde Month"<br>

# %%
df['Order Time'] = pd.to_datetime(df['Order Time'], format="%d-%m-%Y %H:%M")
df['Order Day'] = df['Order Time'].dt.day


df['Order Hour'] = df['Order Time'].dt.hour
df['Order Minute'] = df['Order Time'].dt.minute
df['Orde Month'] = df['Order Time'].dt.month

# %%
df
# Out:
#      Order ID   Restaurant Name     Location          Order Time  \
# 0      770487      El Taco Loco     New York 2024-08-01 14:55:00
# 1      671858      El Taco Loco  San Antonio 2024-11-23 17:11:00
# 2      688508        Taco Haven       Austin 2024-11-21 20:24:00
# 3      944962  Spicy Taco House       Dallas 2024-09-21 06:43:00
# 4      476417     Casa del Taco  San Antonio 2024-07-24 11:01:00
# ..        ...               ...          ...                 ...
# 995    164891      La Vida Taco       Austin 2024-05-27 11:12:00
# 996    232442    The Taco Stand  San Antonio 2025-04-03 20:51:00
# 997    251729       Urban Tacos      Houston 2025-01-23 05:33:00
# 998    940215       Taco Fiesta  San Antonio 2024-09-05 15:49:00
# 999    326183      Grande Tacos      Phoenix 2024-10-19 14:21:00
#
#         Delivery Time  Delivery Duration (min) Taco Size     Taco Type  \
# 0    01-08-2024 15:36                       41   Regular  Chicken Taco
# ...

# %% [markdown]
# ## 4.4 Eliminar columnas innecesarias
#
# Sirve para: Mejorar el rendimiento de modelos y análisis.
#
# Evitar ruido o información irrelevante.

# %% [markdown]
# *El metodo df.drop(columns=["ColumnaAeliminar"], inplace=True)* nos permite eliminar una columna

# %%
df.drop(columns=["Order ID"], inplace=True)
df.head(10)
# Out:
#     Restaurant Name     Location          Order Time     Delivery Time  \
# 0      El Taco Loco     New York 2024-08-01 14:55:00  01-08-2024 15:36
# 1      El Taco Loco  San Antonio 2024-11-23 17:11:00  23-11-2024 17:25
# 2        Taco Haven       Austin 2024-11-21 20:24:00  21-11-2024 21:02
# 3  Spicy Taco House       Dallas 2024-09-21 06:43:00  21-09-2024 07:28
# 4     Casa del Taco  San Antonio 2024-07-24 11:01:00  24-07-2024 11:16
# 5       Urban Tacos  San Antonio 2024-10-07 21:21:00  07-10-2024 22:44
# 6        Taco Haven  Los Angeles 2024-10-22 06:03:00  22-10-2024 06:48
# 7      El Taco Loco  San Antonio 2025-05-08 04:51:00  08-05-2025 05:22
# 8    The Taco Stand      Houston 2024-09-08 21:04:00  08-09-2024 21:21
# 9     Casa del Taco      Houston 2025-05-24 02:15:00  24-05-2025 03:28
#
#    Delivery Duration (min) Taco Size     Taco Type  Toppings Count  \
# 0                       41   Regular  Chicken Taco               5
# ...

# %% [markdown]
# ## 4.5 Busquedad de Valores Outlier

# %% [markdown]
# Usamos un Grafico Boxplot para buscar valores outlier en este caso usamos la columnas cuyo valor sea numericos.

# %%
import seaborn as sns
columnas_numericas = ['Delivery Duration (min)', 'Distance (km)', 'Tip ($)', 'Price ($)']

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[columnas_numericas], orient="h")
plt.title("Detección visual de outliers")
plt.show()

# %% [markdown]
# Dentro del graficos podemos observar que la columna propina(Tip $) contiene valores outliers.
# Usarmos la funcion *describe* para ver los datos en la columna.

# %%
df["Tip ($)"].describe()
# Out:
# count    1000.000000
# mean        1.806110
# std         1.132035
# min         0.010000
# 25%         0.907500
# 50%         1.760000
# 75%         2.520000
# max         4.980000
# Name: Tip ($), dtype: float64

# %% [markdown]
# Vemos que la media es de $1.8 dolares

# %% [markdown]
# Usamos una función basada en IQR para detectar estos valores.

# %%
def marcar_outliers(df, columna):
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    return ~df[columna].between(limite_inferior, limite_superior)

# Añadir una columna booleana
df["Outlier_Tip"] = marcar_outliers(df, "Tip ($)")

# Ver solo los que son outliers
df[df["Outlier_Tip"] == True]
# Out:
#        Restaurant Name   Location          Order Time     Delivery Time  \
# 665  Taco Time Express   San Jose 2024-07-06 19:25:00  06-07-2024 20:50
# 765      Casa del Taco  San Diego 2025-03-29 13:56:00  29-03-2025 14:09
# 798        Urban Tacos    Phoenix 2025-01-18 19:57:00  18-01-2025 20:55
#
#      Delivery Duration (min) Taco Size  Taco Type  Toppings Count  \
# 665                       85   Regular  Pork Taco               2
# 765                       13     Large  Fish Taco               0
# 798                       58   Regular  Fish Taco               1
#
#      Distance (km)  Price ($)  Tip ($)  Weekend Order  Order Day  Order Hour  \
# 665          17.10       5.50     4.97           True          6          19
# 765          10.99       4.50     4.96           True         29          13
# 798          15.20       4.25     4.98           True         18          19
#
#      Order Minute  Orde Month  Outlier_Tip
# 665            25           7         True
# ...

# %% [markdown]
# Los valores encontrados corresponden a propinas que fueron inusuales dentro del promedio entregado dentro de la columna *"Tip ($)"*
