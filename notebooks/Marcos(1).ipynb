# %% [markdown]
# <img src="../img/logoAIEP.jpg" alt="Logo de AIEP" width="300">

# %% [markdown]
# Importar Librerias como Pandas o Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Se importar dataset para la creacion del futuro dataframe (df)

# %%
df = pd.read_csv("../dataset/taco_sales_2024-2025.csv")

# %% [markdown]
# Se utiliza el atributo head para elistar los primero registros del dataframe, para este caso los primeros 10

# %%
df.head(10)
# Out:
#    Order ID   Restaurant Name     Location        Order Time  \
# 0    770487      El Taco Loco     New York  01-08-2024 14:55
# 1    671858      El Taco Loco  San Antonio  23-11-2024 17:11
# 2    688508        Taco Haven       Austin  21-11-2024 20:24
# 3    944962  Spicy Taco House       Dallas  21-09-2024 06:43
# 4    476417     Casa del Taco  San Antonio  24-07-2024 11:01
# 5    678856       Urban Tacos  San Antonio  07-10-2024 21:21
# 6    183667        Taco Haven  Los Angeles  22-10-2024 06:03
# 7    379946      El Taco Loco  San Antonio  08-05-2025 04:51
# 8    771088    The Taco Stand      Houston  08-09-2024 21:04
# 9    694731     Casa del Taco      Houston  24-05-2025 02:15
#
#       Delivery Time  Delivery Duration (min) Taco Size     Taco Type  \
# 0  01-08-2024 15:36                       41   Regular  Chicken Taco
# 1  23-11-2024 17:25                       14   Regular     Beef Taco
# 2  21-11-2024 21:02                       38     Large     Pork Taco
# 3  21-09-2024 07:28                       45   Regular  Chicken Taco
# 4  24-07-2024 11:16                       15     Large     Pork Taco
# 5  07-10-2024 22:44                       83   Regular     Beef Taco
# 6  22-10-2024 06:48                       45     Large   Veggie Taco
# 7  08-05-2025 05:22                       31   Regular  Chicken Taco
# 8  08-09-2024 21:21                       17   Regular     Beef Taco
# 9  24-05-2025 03:28                       73     Large     Fish Taco
#
#    Toppings Count  Distance (km)  Price ($)  Tip ($)  Weekend Order
# 0               5           3.01       9.25     2.22          False
# 1               1           6.20       4.25     3.01           True
# 2               2          20.33       7.00     0.02          False
# 3               2           3.00       5.50     1.90           True
# 4               0          24.34       4.50     1.14          False
# 5               0          16.70       3.00     2.32          False
# 6               1           9.57       5.75     0.63          False
# 7               3           9.80       6.75     2.97          False
# 8               2          10.33       5.50     0.33           True
# 9               1           6.99       5.75     1.23           True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 1000 non-null   int64
#  1   Restaurant Name          1000 non-null   object
#  2   Location                 1000 non-null   object
#  3   Order Time               1000 non-null   object
#  4   Delivery Time            1000 non-null   object
#  5   Delivery Duration (min)  1000 non-null   int64
#  6   Taco Size                1000 non-null   object
#  7   Taco Type                1000 non-null   object
#  8   Toppings Count           1000 non-null   int64
#  9   Distance (km)            1000 non-null   float64
#  10  Price ($)                1000 non-null   float64
#  11  Tip ($)                  1000 non-null   float64
#  12  Weekend Order            1000 non-null   bool
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 94.9+ KB

# %%
df.isnull().sum()
# Out:
# Order ID                   0
# Restaurant Name            0
# Location                   0
# Order Time                 0
# Delivery Time              0
# Delivery Duration (min)    0
# Taco Size                  0
# Taco Type                  0
# Toppings Count             0
# Distance (km)              0
# Price ($)                  0
# Tip ($)                    0
# Weekend Order              0
# dtype: int64

# %% [markdown]
# # Titulo
# ## subtitulo
# cuerpo
# Lista
# * uno
# - dos
# 3. tres

# %% [markdown]
# Graficos de seaborn

# %%
import seaborn as sns
sns.regplot(x='Distance (km)', y='Delivery Duration (min)', data=df)
# Out:
# <Axes: xlabel='Distance (km)', ylabel='Delivery Duration (min)'>

# %% [markdown]
# Graficos de barras

# %%
sns.barplot(x='Taco Type', y='Tip ($)', data=df)
# Out:
# <Axes: xlabel='Taco Type', ylabel='Tip ($)'>

# %% [markdown]
# Barra de cajita con bigotes

# %%
sns.boxplot(x='Taco Size', y='Price ($)', data=df)
# Out:
# <Axes: xlabel='Taco Size', ylabel='Price ($)'>

# %% [markdown]
# Histograma

# %%
df['Delivery Duration (min)'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# Mapa de calor de correlacion

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Only use numeric columns for correlation
corr = df.select_dtypes(include=['number', 'bool']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.sum()
# Out:
# Order ID                                                           552504865
# Restaurant Name            El Taco LocoEl Taco LocoTaco HavenSpicy Taco H...
# Location                   New YorkSan AntonioAustinDallasSan AntonioSan ...
# Order Time                 01-08-2024 14:5523-11-2024 17:1121-11-2024 20:...
# Delivery Time              01-08-2024 15:3623-11-2024 17:2521-11-2024 21:...
# Delivery Duration (min)                                                50930
# Taco Size                  RegularRegularLargeRegularLargeRegularLargeReg...
# Taco Type                  Chicken TacoBeef TacoPork TacoChicken TacoPork...
# Toppings Count                                                          2529
# Distance (km)                                                       13073.42
# Price ($)                                                            6908.25
# Tip ($)                                                              1806.11
# Weekend Order                                                            275
# dtype: object

# %% [markdown]
# df
