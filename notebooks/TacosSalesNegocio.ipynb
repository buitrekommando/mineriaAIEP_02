# %% [markdown]
# <a href="https://colab.research.google.com/github/Bowls23/Bowls23/blob/main/TacosSalesNegocio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🌮 **Taco** **Sales** Dataset
# **Conoce** **el** **Negocio**

# %% [markdown]
# # Proyecto de Minería de Datos – Taco Sales
# ##  Conocer el Negocio
# **Alumno/as:**
#  Camila Garcia
#
#  Jose Heriquez
#
#  Gisselle Rey
#
#  Marcos Zuñiga
#
# **Carrera:** Ingeniería en Informática
# **Ramo:** Introduccion Minería de Datos

# %% [markdown]
# # Negocio: Taco Sales
# # Análisis de datos y del Negocio Taco Sales (2024–2025)
#
# **Empezar** **primero** **por** **saber** **que** **es** **Taco** **Sales**para **entender** **el** **negocio**
#
# Taco Sales es una empresa del sector gastronómico especializada en la venta de tacos bajo un modelo de comida rápida y delivery inteligente. Se trata de un negocio que combina la tradición de la cocina mexicana con una operación moderna, centrada en el uso intensivo de datos operacionales, logísticos y comerciales y tambien representa un modelo de negocio híbrido ya que tambien funciona tanto presencial y delivery, diseñado para operar con una ventaja competitiva basada en la inteligencia de datos como lo son Data-Driven Intelligence. La organización fusiona la oferta de un producto de alta demanda con una infraestructura tecnológica que captura y procesa datos transaccionales, logísticos y el comportamiento del cliente en tiempo real.
#
# # La propuesta de valor del negocio
# Taco Sales no solo se basa en ofrecer tacos deliciosos, personalizables y accesibles, sino en la eficiencia operativa, la tecnología aplicada y el enfoque estratégico basado en datos para su crecimiento.
#
# Y la ventaja competitiva de Taco Sales se construye sobre los siguientes pilares que son muy fundamentales:
#
# **Producto** **atractivo**: Tacos artesanales, adaptables, en distintos tamaños y con múltiples combinaciones.
#
# **Velocidad** **y** **conveniencia**: Modelo express orientado a reducir tiempos de espera. Digitalización y monitoreo: Seguimiento en tiempo real de pedidos, stock y tiempos.
#
# **Toma** **de** **decisiones** basada en datos: Análisis continuo para ajustar menús, precios, promociones y logística.
#
# # Modelo del negocio
# Taco Sales opera a través de una red de restaurantes ubicados en ciudades como:
#
# - New York
#
# - Dallas
#
# - Austin
#
# - San Antonio,
#
# Utilizando un modelo híbrido de atención: como presencial (en tienda)
# Delivery (propio o a través de plataformas como DoorDash y Uber Eats)
# Cada punto de venta funciona con una estructura ágil, enfocada en tiempos de preparación reducidos, variedad de combinaciones, y una experiencia estandarizada para el cliente.
#
# # Qué datos utiliza este negocio
#
# Uno de los principales diferenciales de Taco Sales es que cada interacción del cliente genera datos clave para la toma de decisiones y las variable	en el uso estratégico y asi obtener datos importantes como hora y fecha del pedido	Identificación de patrones de demanda por franja y estacionalidad
#
# En este negocio tambien es importante los datos como la ubicación del cliente,
# segmentación geográfica, planificación logística, tamaño y tipo de taco	Análisis de preferencia del consumidor, cantidad de toppings	Personalización  control de costos, tiempo de entrega	Evaluación de eficiencia operativa,distancia recorrida	Optimización de rutas y reducción de costos, propina entregada	Indicador indirecto de satisfacción del cliente, comparación de comportamiento entre días hábiles y fines de semana
#
#
# # Posicionamiento estratégico del negocio
#
# Taco Sales no compite únicamente por sabor o precio, sino por inteligencia operativa. Mientras muchos negocios gastronómicos se basan en intuición o experiencia previa, Taco Sales avanza con decisiones respaldadas por datos. Esto le permite:
#
# Detectar tendencias antes que la competencia
# Reducir costos operativos sin afectar la calidad
# Diseñar promociones segmentadas por cliente o ciudad
# Prever picos de demanda y reforzar recursos en tiempo real
#
# # Por qué es replicable este modelo?
#
# Taco Sales es un ejemplo moderno de cómo la gastronomía puede cruzarse con la ciencia de datos. Su negocio no solo ofrece un producto exitoso y deseado, sino que está diseñado para aprender constantemente del comportamiento del cliente, adaptarse con rapidez y crecer con inteligencia. Este proyecto permite analizar no solo los datos de venta, sino también el funcionamiento interno de una organización preparada para el futuro digital del rubro alimenticio.
# ¿Quieres que prepare este texto como celda Markdown para Google Colab o que lo exporte a Word o PDF? También puedo hacer una versión con gráficas o visuales del modelo de negocio si tu entrega lo requiere.

# %% [markdown]
# # **Problemas de Negocio que Aborda el Dataset de Ventas de Tacos**
#
# 1. fluctuación en la Demanda:
# Uno de los principales problemas de la industria gastronómica, especialmente en la comida rápida, es la fluctuación en la demanda. Esto puede generar desperdicios de comida o falta de insumos. El dataset puede ayudar a analizar las variaciones de demanda en diferentes días, semanas o meses, y así poder prever con más precisión la cantidad de ingredientes necesarios para cada día.
#
# 2. optimización de Inventarios:
# Sin un sistema adecuado de gestión de inventarios, los negocios pueden enfrentar pérdidas de productos perecederos como tortillas, carne, salsa, etc. Con los datos del dataset, los dueños de los restaurantes pueden optimizar el control de insumos, reduciendo desperdicios y mejorando la rentabilidad.
#
# 3. identificación de Tendencias de Consumo:
# Este dataset ofrece una visión importante sobre qué tipo de tacos tienen mayor demanda, en qué zonas geográficas se consume más y en qué días de la semana se concentran los pedidos. Esto ayuda a las marcas a realizar una planificación adecuada de su producción y estrategia de marketing.

# %% [markdown]
# # **Oportunidades para el Negocio de Tacos en Chile**
#
# Expansión en Nuevas Zonas Geográficas:
# El análisis de las zonas con mayor demanda puede revelar nuevas oportunidades de expansión. Un negocio exitoso de tacos podría considerar abrir nuevas ubicaciones en zonas con alta densidad poblacional o expandirse a ciudades fuera de Santiago, como Viña del Mar o Concepción, donde la comida mexicana comienza a ser más popular.
#
# Promociones Específicas:
# Con la información sobre los días de mayor y menor demanda, las marcas pueden diseñar ofertas y promociones para los días más tranquilos, como el lunes o martes, aumentando las ventas en días de baja demanda.
#
# Personalización de Menú:
# Adaptarse a las preferencias locales también es una forma de innovar. Ofrecer tacos con ingredientes que resuenen con los gustos de los chilenos, como tacos de pescado frito, carne de cordero o incluso tacos con productos típicos como avellanas y frutillas puede atraer a más clientes.

# %% [markdown]
# ## 📊 ¿Qué datos utiliza este tipo de negocio?
#
# **La** **siguiente** **tabla** **resume** **las** **variables** **más** **importantes** **del** **dataset** **y** **cómo** **son** **utilizadas** **estratégicamente** **por** **Taco** **Sales**.

# %%
import pandas as pd
from IPython.display import display, Markdown

# DATOS MAS REVELANTES EN ESTE NEGOCIOO
display(Markdown("### 📊 ¿Qué datos utiliza este tipo de negocio?"))

# Crear el DataFrame
datos_negocio = {
    "Variable": [
        "Hora y fecha del pedido",
        "Ubicación del cliente",
        "Tamaño y tipo de taco",
        "Cantidad de toppings",
        "Tiempo de entrega",
        "Distancia recorrida",
        "Propina entregada",
        "¿Fue fin de semana?"
    ],
    "Uso estratégico": [
        "Identificación de patrones de demanda por franja y estacionalidad",
        "Segmentación geográfica y planificación logística",
        "Análisis de preferencia del consumidor",
        "Personalización y control de costos",
        "Evaluación de eficiencia operativa",
        "Optimización de rutas y reducción de costos",
        "Indicador indirecto de satisfacción del cliente",
        "Comparación de comportamiento entre días hábiles y fines de semana"
    ]
}

df_estrategia = pd.DataFrame(datos_negocio)


display(df_estrategia)
# Out:
# ### 📊 ¿Qué datos utiliza este tipo de negocio?
#                   Variable                                    Uso estratégico
# 0  Hora y fecha del pedido  Identificación de patrones de demanda por fran...
# 1    Ubicación del cliente  Segmentación geográfica y planificación logística
# 2    Tamaño y tipo de taco             Análisis de preferencia del consumidor
# 3     Cantidad de toppings                Personalización y control de costos
# 4        Tiempo de entrega                 Evaluación de eficiencia operativa
# 5      Distancia recorrida        Optimización de rutas y reducción de costos
# 6        Propina entregada    Indicador indirecto de satisfacción del cliente
# 7      ¿Fue fin de semana?  Comparación de comportamiento entre días hábil...

# %% [markdown]
# ## 📊 La inteligencia de Negocio de Tacos Sales
#
# **Aca** **se** **muestra** **el** **proceso** **del** **proceso** **de** **datos** **para** **este** **negocio**

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# --- Datos estructurados para el diagrama ---
data_pipeline = {
    'Captura del Dato': [
        'Ubicación del cliente',
        'Tipo y tamaño de taco',
        'Cantidad de toppings',
        'Tiempo de entrega',
        'Distancia recorrida',
        'Propina entregada',
        'Patrones de día'
    ],
    'Análisis Aplicado': [
        'Segmentación Geográfica',
        'Análisis de Preferencias',
        'Control de Costos',
        'Evaluación de Eficiencia',
        'Optimización de Rutas',
        'Medición de Satisfacción',
        'Análisis Comparativo'
    ],
    'Decisión Estratégica': [
        'Planificación de Marketing',
        'Ingeniería de Menú',
        'Ajuste de Precios',
        'Mejora de Operaciones',
        'Reducción de Gastos',
        'Programas de Lealtad',
        'Gestión de Demanda'
    ]
}

# --- Creación de la visualización ---
fig, ax = plt.subplots(figsize=(20, 10))
fig.set_facecolor("#F8F9FA")

# Propiedades de las cajas y flechas
box_style = dict(boxstyle='round,pad=0.5', fc='#FFFFFF', ec='#ADB5BD', lw=1.5)
arrow_style = dict(arrowstyle='-|>', color='#6C757D', lw=2, mutation_scale=20)
y_pos = 0.5
x_positions = [0.15, 0.5, 0.85]
stage_titles = ['1. Captura del Dato', '2. Análisis Aplicado', '3. Decisión Estratégica']
colors = ['#005A9C', '#0077B6', '#0096C7'] # Tonos de azul

for i, (stage_title, data_list) in enumerate(data_pipeline.items()):
    x = x_positions[i]

    # Unir la lista de datos en un solo bloque de texto
    text_content = '\n'.join(f'• {item}' for item in data_list)

    # Dibujar la caja principal con el texto
    ax.text(x, y_pos, text_content, ha='center', va='center', fontsize=12, color='#495057',
            bbox=box_style, linespacing=1.6)

    # Añadir el título del escenario
    ax.text(x, 0.9, stage_title, ha='center', va='center', fontsize=16,
            fontweight='bold', color=colors[i])

# Dibujar las flechas conectando las etapas
for i in range(len(x_positions) - 1):
    arrow = patches.FancyArrowPatch(
        (x_positions[i] + 0.15, y_pos),
        (x_positions[i+1] - 0.15, y_pos),
        connectionstyle="arc3,rad=0",
        **arrow_style
    )
    ax.add_patch(arrow)

# Formato final del gráfico
ax.axis('off')
ax.set_ylim(0, 1)
ax.set_xlim(0, 1)
plt.suptitle('Pipeline de Inteligencia de Negocio: Taco Sales', fontsize=24, fontweight='bold', color='#212529')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ## 📊 ¿Qué datos utiliza este tipo de negocio?
#
# **La** **siguiente** **tabla** **resume** **las** **variables** **más** **importantes** **del** **dataset** **y** **cómo** **son** **utilizadas** **estratégicamente** **por** **Taco** **Sales**.**texto en negrita**

# %%
import pandas as pd
from IPython.display import display, HTML # seuso display para el modelo de dataframe

datos_originales = {
    'ID PEDIDO': [1001, 1002, 1003, 1004],
    'NOMBRE DEL RESTAURANTE': ['Taco Express', 'Tacos del Sol', 'Taco Express', 'La Frontera'],
    'UBICACION': ['New York', 'Dallas', 'Austin', 'San Antonio'],
    'TIEMPO DE ORDEN': ['12:30:15', '19:45:02', '13:15:55', '20:05:10'],
    'EL TIEMPO DE ENTREGA': ['12:55:30', '20:15:10', '13:40:05', '20:28:00'],
    'DURACIÓN DE LA ENTREGA (min)': [25, 30, 24, 22],
    'TAMAÑO DE TACOS': ['Large', 'Medium', 'Large', 'Medium'],
    'TIPO DE TACO': ['Carne Asada', 'Pollo', 'Barbacoa', 'Carnitas'],
    'Toppings': [4, 3, 5, 4],
    'DISTANCIA (km)': [3.5, 5.2, 4.1, 3.8],
    'PRECIO ($)': [12.50, 9.75, 14.00, 11.50],
    'PROPINA ($)': [2.00, 1.50, 2.50, 2.00],
    'MEJOR SEMANA': [False, True, False, True]
}
df = pd.DataFrame(datos_originales)


print("EJEMPLOS DE DATOS MAS REVELANTES EN EL NEGOCIO ")
display(df)
# Out:
# EJEMPLOS DE DATOS MAS REVELANTES EN EL NEGOCIO
#    ID PEDIDO NOMBRE DEL RESTAURANTE    UBICACION TIEMPO DE ORDEN  \
# 0       1001           Taco Express     New York        12:30:15
# 1       1002          Tacos del Sol       Dallas        19:45:02
# 2       1003           Taco Express       Austin        13:15:55
# 3       1004            La Frontera  San Antonio        20:05:10
#
#   EL TIEMPO DE ENTREGA  DURACIÓN DE LA ENTREGA (min) TAMAÑO DE TACOS  \
# 0             12:55:30                            25           Large
# 1             20:15:10                            30          Medium
# 2             13:40:05                            24           Large
# 3             20:28:00                            22          Medium
#
#   TIPO DE TACO  Toppings  DISTANCIA (km)  PRECIO ($)  PROPINA ($)  \
# 0  Carne Asada         4             3.5       12.50          2.0
# 1        Pollo         3             5.2        9.75          1.5
# ...

# %% [markdown]
# ## 🕒 Un poco de la Historia del Negocio
#
# La siguiente línea de tiempo muestra los hitos más relevantes del desarrollo del modelo Taco Sales, desde su conceptualización hasta su proyección de expansión a Chile.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

eventos = {
    "Fecha": [
        "2020-01-01", "2021-06-15", "2022-03-10",
        "2023-08-05", "2024-01-01", "2025-06-01"
    ],
    "Evento": [
        "Idea inicial del negocio: tacos personalizados con modelo basado en datos.",
        "Primera sucursal en Austin, TX: validación de mercado.",
        "Sistema de pedidos con captura de datos por cliente.",
        "Expansión a Dallas, San Antonio y New York.",
        "Aplicación de analítica para optimizar logística.",
        "Evaluación del mercado chileno para replicar el modelo."
    ]
}

df_eventos = pd.DataFrame(eventos)
df_eventos["Fecha"] = pd.to_datetime(df_eventos["Fecha"])

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df_eventos["Fecha"], [1]*len(df_eventos), "o", color="saddlebrown")

for i, row in df_eventos.iterrows():
    ax.plot([row["Fecha"], row["Fecha"]], [1, 1.05], color="gray", linestyle="--")
    ax.text(row["Fecha"], 1.07, row["Evento"], ha='center', va='bottom', rotation=45, fontsize=9)

ax.get_yaxis().set_visible(False)
ax.set_title("Historia del Negocio", fontsize=14, fontweight='bold')
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ACA SE DESCARGO EL DATASET

# %%
# Crear carpeta .kaggle y mover el archivo
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Descargar el dataset de tacos
# !kaggle datasets download -d atharvasoundankar/taco-sales-dataset-20242025
# Out:
# Dataset URL: https://www.kaggle.com/datasets/atharvasoundankar/taco-sales-dataset-20242025
# License(s): MIT
# ...
#   0% 0.00/27.4k [00:00<?, ?B/s]
# 100% 27.4k/27.4k [00:00<00:00, 99.5MB/s]

# %%
# Descomprimir
# !unzip -o taco_sales_dataset.csv.zip
# Out:
# unzip:  cannot find or open taco_sales_dataset.csv.zip, taco_sales_dataset.csv.zip.zip or taco_sales_dataset.csv.zip.ZIP.
